# %%
import numpy as np
# !pip install scikit-learn
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn import datasets
x,y,coef=datasets.make_regression(n_samples=100,n_features=1,n_informative=1,noise=10,
coef=True,random_state=0)
#Scale the feature of x for exp from 0 to 20
x = np.interp(x,(x.min(),x.max()),(0,20))
len(x)
print(x)
y = np.interp(y,(y.min(),y.max()),(20000,150000))
len(y)
print(y)
# Out:
# [[ 9.09621765]
#  [14.63742853]
#  [12.25580785]
#  [ 7.21515957]
#  [ 6.90562848]
#  [12.42799856]
#  [ 6.53450315]
#  [12.36358975]
#  [11.45101022]
#  [ 9.29527704]
#  [ 8.46897323]
#  [11.11359701]
#  [ 4.21646281]
#  [ 8.92109838]
#  [13.29785748]
#  [15.47570863]
#  [ 9.84113925]
#  [17.99332461]
#  [16.61818648]
#  [ 7.74737185]
#  [14.6461329 ]
#  [18.44957388]
#  [ 8.7705892 ]
#  [11.88558736]
#  [13.74332637]
#  [13.81155569]
#  [18.67718793]
#  [11.97104337]
#  [ 9.14449312]
#  [16.94375093]
#  [ 6.87377602]
#  [ 8.18679147]
#  [ 6.2389242 ]
#  [12.15553663]
#  [10.63083424]
#  [12.50645606]
#  [11.18464153]
#  [ 8.9153091 ]
#  [10.80270889]
#  [ 5.39192765]
#  [14.96011903]
#  [12.24674897]
#  [ 3.51136012]
#  [19.8803112 ]
#  [11.3230796 ]
#  [ 9.73649581]
#  [15.68932604]
#  [ 7.0453415 ]
#  [17.90284439]
#  [12.29004918]
#  [ 6.82470934]
#  [ 4.69845289]
#  [12.51840023]
#  [14.32303265]
#  [15.31240374]
#  [12.25434694]
#  [12.19178147]
#  [ 3.42836832]
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(x,y,'.',label='training data')
plt.xlabel('Years of experience')
plt.ylabel('Salary')
plt.title('Experience vs Salary')
# Out:
# Text(0.5, 1.0, 'Experience vs Salary')

# %%
from sklearn.linear_model import LinearRegression
reg_model = LinearRegression()
reg_model.fit(x,y)
y_predicted=reg_model.predict(x)
plt.plot(x,y_predicted,'.',color="black")
plt.plot(x,y,".",label="training data")
plt.plot(x,y,'.',label="training data")
plt.xlabel("Years of experience")
plt.ylabel("Salary")
plt.title("Experience vs salary")
plt.legend()

# %%
from sklearn.linear_model import LinearRegression
import numpy as np
import matplotlib.pyplot as plt
reg_model = LinearRegression()
x=np.random.rand(100,1)
error=np.random.rand(100,1)
b0=10
b1=7
y=b0+b1*x+error
reg_model.fit(x,y)
y_predicted=reg_model.predict(x)
plt.plot(x,y_predicted,'.',color="black",label="Predicted data")
plt.plot(x,y,'.',label="Training data")
plt.xlabel("X")
plt.ylabel("Y")
plt.title("X vs Y")
plt.legend()

# %%
# 4. Train Linear Regression model
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
# 5. Predict on the same data (for visualization)
y_pred = model.predict(X)

# %%
# 6. Print model parameters
print(f"Intercept (base salary) : ₹{model.intercept_:.2f}")
print(f"Slope (₹ per year)      : ₹{model.coef_[0]:.2f}")
# Out:
# Intercept (base salary) : ₹22755.18
# Slope (₹ per year)      : ₹6367.64

# %%
# 7. Visualization
plt.figure(figsize=(9, 6))
plt.scatter(X, y, color='blue', alpha=0.6, label='Actual Data (Training)')
plt.plot(X, y_pred, color='red', linewidth=2.5, label='Linear Regression Fit')
plt.xlabel("Years of Experience")
plt.ylabel("Salary (₹)")
plt.title("Experience vs Salary – Linear Regression")
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# 8. Example prediction (outside training range)
experience_new = np.array([[22.0]])  # 22 years
predicted_salary = model.predict(experience_new)
print(f"Predicted salary for 22 years of experience: ₹{predicted_salary[0]:.2f}")
# Out:
# Predicted salary for 22 years of experience: ₹162843.24

# %%
#Simulate Linear Model: y = 10 + 7x + e (100 samples)

# %%
# Import libraries
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# Set random seed for reproducibility
np.random.seed(42)

# 1. Simulate data: y = 10 + 7x + e
n_samples = 100
X = np.random.rand(n_samples, 1)          # X in [0, 1)
error = np.random.randn(n_samples, 1) * 1.5  # Gaussian noise (std ≈ 1.5)
y = 10 + 7 * X + error

# 2. Train Linear Regression model
model = LinearRegression()
model.fit(X, y)

# 3. Predict
y_pred = model.predict(X)

# 4. Print recovered parameters (should be close to 10 and 7)
print(f"Intercept (b0) : {model.intercept_[0]:.4f}  (true = 10)")
print(f"Slope (b1)     : {model.coef_[0][0]:.4f}     (true = 7)")

# 5. Visualization
plt.figure(figsize=(9, 6))
plt.scatter(X, y, color='teal', alpha=0.7, label='Noisy Data (y = 10 + 7x + e)')
plt.plot(X, y_pred, color='darkorange', linewidth=2.8, label='Fitted Line')
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Simulated Linear Relationship with Noise + Regression Fit")
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Intercept (b0) : 10.3226  (true = 10)
# Slope (b1)     : 6.3103     (true = 7)
